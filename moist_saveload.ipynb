# %%
import os
import tensorflow as tf
from tensorflow import keras

# step1 加载mnist数据
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()
x_test, x_train = x_test / 255.0, x_train / 255.0
x_test, x_train = x_test.reshape(-1, 28*28), x_train.reshape(-1, 28*28)

# step2 create model
def create_model():
    return keras.Sequential([
            keras.layers.Dense(256, activation='relu'),
            keras.layers.Dense(128, activation='relu'),
            keras.layers.Dense(64, activation='relu'),
            keras.layers.Dense(10, activation='softmax')
])
model = create_model()

# step3 configurate model
model.compile(optimizer='sgd', loss='sparse_categorical_crossentropy', metrics=['accuracy'])


# step4 模型训练  训练一个epochs
model.fit(x=x_train,
          y=y_train,
          epochs=1,
          )

# step5 模型测试
loss, acc = model.evaluate(x_test, y_test)
print("train model, accuracy:{:5.2f}%".format(100 * acc))
# Out:
# Train on 60000 samples
# 60000/60000 [==============================] - 6s 101us/sample - loss: 0.6302 - accuracy: 0.8267
# ...

# %%
# step6 保存模型的权重和偏置
# model.save_weights('my_save_weights.h5')
model.save('my_save.h5')
del model

# %%
# step7 reload weight matrix
# model = create_model()
# model.compile(optimizer='sgd', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# model.load_weights('my_save_weights.h5')

model = keras.models.load_model('my_save.h5')
model.summary()
# step10 测试模型
loss, acc = model.evaluate(x_test, y_test)
print("Restored model, accuracy:{:5.2f}%".format(100 * acc))
#print(model.get_weights())
# Out:
# WARNING:tensorflow:Sequential models without an `input_shape` passed to the first layer cannot reload their optimizer state. As a result, your model isstarting with a freshly initialized optimizer.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_4 (Dense)              multiple                  200960
# _________________________________________________________________
# dense_5 (Dense)              multiple                  32896
# _________________________________________________________________
# dense_6 (Dense)              multiple                  8256
# _________________________________________________________________
# dense_7 (Dense)              multiple                  650
# ...
# Total params: 242,762
# Trainable params: 242,762
# Non-trainable params: 0
# _________________________________________________________________
# ...
