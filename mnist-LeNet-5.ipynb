# %%
import os
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, Sequential

(x_in, y_in), (x_val, y_val) = keras.datasets.mnist.load_data()

network = Sequential([
            layers.Conv2D(6, kernel_size=3, strides=1), 
            layers.MaxPooling2D(pool_size=2, strides=2),
            layers.ReLU(),
            layers.Conv2D(16, kernel_size=3, strides=1),
            layers.MaxPooling2D(pool_size=2, strides=2),
            layers.ReLU(),
            layers.Flatten(),
            layers.Dense(120),
            layers.ReLU(),
            layers.Dense(84),
            layers.ReLU(),
            layers.Dense(10),
            layers.Softmax() # 如果使用CategoricalCrossentropy(from_logits=True)，则不加这句
])
# network.build(input_shape=(4, 28, 28, 1)) # 这里的4即为后面的batch_size
# network.summary()

# 训练网络
'''
x_in = tf.expand_dims((tf.convert_to_tensor(x_in, dtype=tf.float32) / 255.0), axis=-1)
y_in = tf.one_hot(tf.convert_to_tensor(y_in, dtype=tf.int32), depth=10)
train_data = tf.data.Dataset.from_tensor_slices((x_in, y_in)) # 注意这里的括号层数，只能接收一个变量
train_data = train_data.batch(4)


# 通过设定from_logits=True标志位将softmax激活函数实现在损失函数中，这样就不需要手动添加损失函数，提升数值计算稳定性。
# 是否可以理解为在训练时避免使用softmax，能够提升训练效果，需要时再用softmax输出为概率
criteon = keras.losses.CategoricalCrossentropy(from_logits=True) 
optimizer = keras.optimizers.Adam(learning_rate=0.001)


for epoch in range(1):
    for step, (x, y) in enumerate(train_data):
        with tf.GradientTape() as tape:
            # 前向计算
            out = network(x)
            # 计算交叉熵损失函数，标量
            loss = criteon(y, out)
        # 梯度计算、优化
        grads = tape.gradient(loss, network.trainable_variables)
        optimizer.apply_gradients(zip(grads, network.trainable_variables))
        if step%4 == 0 :
            print(epoch, loss)
'''

x_in = tf.expand_dims((tf.convert_to_tensor(x_in, dtype=tf.float32) / 255.0), axis=-1)
y_in = tf.one_hot(tf.convert_to_tensor(y_in, dtype=tf.int32), depth=10)

print(x_in.shape)
network.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy']) # 使用交叉熵作为loss函数    

network.fit(x_in, y_in, batch_size=4, epochs=1, 
             validation_split=0.1)
# Out:
# (60000, 28, 28, 1)
# Train on 54000 samples, validate on 6000 samples
# 54000/54000 [==============================] - 134s 2ms/sample - loss: 0.1401 - accuracy: 0.9567 - val_loss: 0.0708 - val_accuracy: 0.9815

# %%
network.save('mnist-lenet5.h5')

# %%
del model

# %%
network = models.load_model('mnist-lenet5.h5')

# %%
(x_in, y_in), (x_val, y_val) = keras.datasets.mnist.load_data()
x_val = tf.convert_to_tensor(x_val/255.0, dtype=tf.float32)
y_val = tf.convert_to_tensor(y_val, dtype=tf.int32)
test_dataset = tf.data.Dataset.from_tensor_slices((x_val, y_val))
test_dataset = test_dataset.batch(1)
# 测试模型
correct, total = 0, 0
for x, y in test_dataset:
    x = tf.expand_dims(x, axis=-1)
    out = network(x)
    # softmax不改变元素大小相对关系，因此省去（以概率选择第一个值时，都可以省去？）
    pred = tf.argmax(out, axis=-1) 
    y = tf.cast(y, tf.int64)
    correct += float(tf.reduce_sum(tf.cast(tf.equal(pred, y), tf.float32)))
    total += x.shape[0]
    print(total, tf.equal(pred, y))
print('test acc:', correct/total)
# Out:
# 1 tf.Tensor([ True], shape=(1,), dtype=bool)
# 2 tf.Tensor([ True], shape=(1,), dtype=bool)
# 3 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5 tf.Tensor([ True], shape=(1,), dtype=bool)
# 6 tf.Tensor([ True], shape=(1,), dtype=bool)
# 7 tf.Tensor([ True], shape=(1,), dtype=bool)
# 8 tf.Tensor([ True], shape=(1,), dtype=bool)
# 9 tf.Tensor([ True], shape=(1,), dtype=bool)
# 10 tf.Tensor([ True], shape=(1,), dtype=bool)
# 11 tf.Tensor([ True], shape=(1,), dtype=bool)
# 12 tf.Tensor([ True], shape=(1,), dtype=bool)
# 13 tf.Tensor([ True], shape=(1,), dtype=bool)
# 14 tf.Tensor([ True], shape=(1,), dtype=bool)
# 15 tf.Tensor([ True], shape=(1,), dtype=bool)
# 16 tf.Tensor([ True], shape=(1,), dtype=bool)
# 17 tf.Tensor([ True], shape=(1,), dtype=bool)
# 18 tf.Tensor([ True], shape=(1,), dtype=bool)
# 19 tf.Tensor([ True], shape=(1,), dtype=bool)
# 20 tf.Tensor([ True], shape=(1,), dtype=bool)
# 21 tf.Tensor([ True], shape=(1,), dtype=bool)
# 22 tf.Tensor([ True], shape=(1,), dtype=bool)
# 23 tf.Tensor([ True], shape=(1,), dtype=bool)
# 24 tf.Tensor([ True], shape=(1,), dtype=bool)
# 25 tf.Tensor([ True], shape=(1,), dtype=bool)
# 26 tf.Tensor([ True], shape=(1,), dtype=bool)
# 27 tf.Tensor([ True], shape=(1,), dtype=bool)
# 28 tf.Tensor([ True], shape=(1,), dtype=bool)
# 29 tf.Tensor([ True], shape=(1,), dtype=bool)
# 30 tf.Tensor([ True], shape=(1,), dtype=bool)
# 31 tf.Tensor([ True], shape=(1,), dtype=bool)
# 32 tf.Tensor([ True], shape=(1,), dtype=bool)
# 33 tf.Tensor([ True], shape=(1,), dtype=bool)
# 34 tf.Tensor([ True], shape=(1,), dtype=bool)
# 35 tf.Tensor([ True], shape=(1,), dtype=bool)
# 36 tf.Tensor([ True], shape=(1,), dtype=bool)
# 37 tf.Tensor([ True], shape=(1,), dtype=bool)
# 38 tf.Tensor([ True], shape=(1,), dtype=bool)
# 39 tf.Tensor([ True], shape=(1,), dtype=bool)
# 40 tf.Tensor([ True], shape=(1,), dtype=bool)
# 41 tf.Tensor([ True], shape=(1,), dtype=bool)
# 42 tf.Tensor([ True], shape=(1,), dtype=bool)
# 43 tf.Tensor([ True], shape=(1,), dtype=bool)
# 44 tf.Tensor([ True], shape=(1,), dtype=bool)
# 45 tf.Tensor([ True], shape=(1,), dtype=bool)
# 46 tf.Tensor([ True], shape=(1,), dtype=bool)
# 47 tf.Tensor([ True], shape=(1,), dtype=bool)
# 48 tf.Tensor([ True], shape=(1,), dtype=bool)
# 49 tf.Tensor([ True], shape=(1,), dtype=bool)
# 50 tf.Tensor([ True], shape=(1,), dtype=bool)
# 51 tf.Tensor([ True], shape=(1,), dtype=bool)
# 52 tf.Tensor([ True], shape=(1,), dtype=bool)
# 53 tf.Tensor([ True], shape=(1,), dtype=bool)
# 54 tf.Tensor([ True], shape=(1,), dtype=bool)
# 55 tf.Tensor([ True], shape=(1,), dtype=bool)
# 56 tf.Tensor([ True], shape=(1,), dtype=bool)
# 57 tf.Tensor([ True], shape=(1,), dtype=bool)
# 58 tf.Tensor([ True], shape=(1,), dtype=bool)
# 59 tf.Tensor([ True], shape=(1,), dtype=bool)
# 60 tf.Tensor([ True], shape=(1,), dtype=bool)
# 61 tf.Tensor([ True], shape=(1,), dtype=bool)
# 62 tf.Tensor([ True], shape=(1,), dtype=bool)
# 63 tf.Tensor([ True], shape=(1,), dtype=bool)
# 64 tf.Tensor([ True], shape=(1,), dtype=bool)
# 65 tf.Tensor([ True], shape=(1,), dtype=bool)
# 66 tf.Tensor([ True], shape=(1,), dtype=bool)
# 67 tf.Tensor([ True], shape=(1,), dtype=bool)
# 68 tf.Tensor([ True], shape=(1,), dtype=bool)
# 69 tf.Tensor([ True], shape=(1,), dtype=bool)
# 70 tf.Tensor([ True], shape=(1,), dtype=bool)
# 71 tf.Tensor([ True], shape=(1,), dtype=bool)
# 72 tf.Tensor([ True], shape=(1,), dtype=bool)
# 73 tf.Tensor([ True], shape=(1,), dtype=bool)
# 74 tf.Tensor([ True], shape=(1,), dtype=bool)
# 75 tf.Tensor([ True], shape=(1,), dtype=bool)
# 76 tf.Tensor([ True], shape=(1,), dtype=bool)
# 77 tf.Tensor([ True], shape=(1,), dtype=bool)
# 78 tf.Tensor([ True], shape=(1,), dtype=bool)
# 79 tf.Tensor([ True], shape=(1,), dtype=bool)
# 80 tf.Tensor([ True], shape=(1,), dtype=bool)
# 81 tf.Tensor([ True], shape=(1,), dtype=bool)
# 82 tf.Tensor([ True], shape=(1,), dtype=bool)
# 83 tf.Tensor([ True], shape=(1,), dtype=bool)
# 84 tf.Tensor([ True], shape=(1,), dtype=bool)
# 85 tf.Tensor([ True], shape=(1,), dtype=bool)
# 86 tf.Tensor([ True], shape=(1,), dtype=bool)
# 87 tf.Tensor([ True], shape=(1,), dtype=bool)
# 88 tf.Tensor([ True], shape=(1,), dtype=bool)
# 89 tf.Tensor([ True], shape=(1,), dtype=bool)
# 90 tf.Tensor([ True], shape=(1,), dtype=bool)
# 91 tf.Tensor([ True], shape=(1,), dtype=bool)
# 92 tf.Tensor([ True], shape=(1,), dtype=bool)
# 93 tf.Tensor([ True], shape=(1,), dtype=bool)
# 94 tf.Tensor([ True], shape=(1,), dtype=bool)
# 95 tf.Tensor([ True], shape=(1,), dtype=bool)
# 96 tf.Tensor([ True], shape=(1,), dtype=bool)
# 97 tf.Tensor([ True], shape=(1,), dtype=bool)
# 98 tf.Tensor([ True], shape=(1,), dtype=bool)
# 99 tf.Tensor([ True], shape=(1,), dtype=bool)
# 100 tf.Tensor([ True], shape=(1,), dtype=bool)
# 101 tf.Tensor([ True], shape=(1,), dtype=bool)
# 102 tf.Tensor([ True], shape=(1,), dtype=bool)
# 103 tf.Tensor([ True], shape=(1,), dtype=bool)
# 104 tf.Tensor([ True], shape=(1,), dtype=bool)
# 105 tf.Tensor([ True], shape=(1,), dtype=bool)
# 106 tf.Tensor([ True], shape=(1,), dtype=bool)
# 107 tf.Tensor([ True], shape=(1,), dtype=bool)
# 108 tf.Tensor([ True], shape=(1,), dtype=bool)
# 109 tf.Tensor([ True], shape=(1,), dtype=bool)
# 110 tf.Tensor([ True], shape=(1,), dtype=bool)
# 111 tf.Tensor([ True], shape=(1,), dtype=bool)
# 112 tf.Tensor([ True], shape=(1,), dtype=bool)
# 113 tf.Tensor([ True], shape=(1,), dtype=bool)
# 114 tf.Tensor([ True], shape=(1,), dtype=bool)
# 115 tf.Tensor([ True], shape=(1,), dtype=bool)
# 116 tf.Tensor([ True], shape=(1,), dtype=bool)
# 117 tf.Tensor([ True], shape=(1,), dtype=bool)
# 118 tf.Tensor([ True], shape=(1,), dtype=bool)
# 119 tf.Tensor([ True], shape=(1,), dtype=bool)
# 120 tf.Tensor([ True], shape=(1,), dtype=bool)
# 121 tf.Tensor([ True], shape=(1,), dtype=bool)
# 122 tf.Tensor([ True], shape=(1,), dtype=bool)
# 123 tf.Tensor([ True], shape=(1,), dtype=bool)
# 124 tf.Tensor([ True], shape=(1,), dtype=bool)
# 125 tf.Tensor([ True], shape=(1,), dtype=bool)
# 126 tf.Tensor([ True], shape=(1,), dtype=bool)
# 127 tf.Tensor([ True], shape=(1,), dtype=bool)
# 128 tf.Tensor([ True], shape=(1,), dtype=bool)
# 129 tf.Tensor([ True], shape=(1,), dtype=bool)
# 130 tf.Tensor([ True], shape=(1,), dtype=bool)
# 131 tf.Tensor([ True], shape=(1,), dtype=bool)
# 132 tf.Tensor([ True], shape=(1,), dtype=bool)
# 133 tf.Tensor([ True], shape=(1,), dtype=bool)
# 134 tf.Tensor([ True], shape=(1,), dtype=bool)
# 135 tf.Tensor([ True], shape=(1,), dtype=bool)
# 136 tf.Tensor([ True], shape=(1,), dtype=bool)
# 137 tf.Tensor([ True], shape=(1,), dtype=bool)
# 138 tf.Tensor([ True], shape=(1,), dtype=bool)
# 139 tf.Tensor([ True], shape=(1,), dtype=bool)
# 140 tf.Tensor([ True], shape=(1,), dtype=bool)
# 141 tf.Tensor([ True], shape=(1,), dtype=bool)
# 142 tf.Tensor([ True], shape=(1,), dtype=bool)
# 143 tf.Tensor([ True], shape=(1,), dtype=bool)
# 144 tf.Tensor([ True], shape=(1,), dtype=bool)
# 145 tf.Tensor([ True], shape=(1,), dtype=bool)
# 146 tf.Tensor([ True], shape=(1,), dtype=bool)
# 147 tf.Tensor([ True], shape=(1,), dtype=bool)
# 148 tf.Tensor([ True], shape=(1,), dtype=bool)
# 149 tf.Tensor([ True], shape=(1,), dtype=bool)
# 150 tf.Tensor([ True], shape=(1,), dtype=bool)
# 151 tf.Tensor([ True], shape=(1,), dtype=bool)
# 152 tf.Tensor([ True], shape=(1,), dtype=bool)
# 153 tf.Tensor([ True], shape=(1,), dtype=bool)
# 154 tf.Tensor([ True], shape=(1,), dtype=bool)
# 155 tf.Tensor([ True], shape=(1,), dtype=bool)
# 156 tf.Tensor([ True], shape=(1,), dtype=bool)
# 157 tf.Tensor([ True], shape=(1,), dtype=bool)
# 158 tf.Tensor([ True], shape=(1,), dtype=bool)
# 159 tf.Tensor([ True], shape=(1,), dtype=bool)
# 160 tf.Tensor([ True], shape=(1,), dtype=bool)
# 161 tf.Tensor([ True], shape=(1,), dtype=bool)
# 162 tf.Tensor([ True], shape=(1,), dtype=bool)
# 163 tf.Tensor([ True], shape=(1,), dtype=bool)
# 164 tf.Tensor([ True], shape=(1,), dtype=bool)
# 165 tf.Tensor([ True], shape=(1,), dtype=bool)
# 166 tf.Tensor([ True], shape=(1,), dtype=bool)
# 167 tf.Tensor([ True], shape=(1,), dtype=bool)
# 168 tf.Tensor([ True], shape=(1,), dtype=bool)
# 169 tf.Tensor([ True], shape=(1,), dtype=bool)
# 170 tf.Tensor([ True], shape=(1,), dtype=bool)
# 171 tf.Tensor([ True], shape=(1,), dtype=bool)
# 172 tf.Tensor([ True], shape=(1,), dtype=bool)
# 173 tf.Tensor([ True], shape=(1,), dtype=bool)
# 174 tf.Tensor([ True], shape=(1,), dtype=bool)
# 175 tf.Tensor([ True], shape=(1,), dtype=bool)
# 176 tf.Tensor([ True], shape=(1,), dtype=bool)
# 177 tf.Tensor([ True], shape=(1,), dtype=bool)
# 178 tf.Tensor([ True], shape=(1,), dtype=bool)
# 179 tf.Tensor([ True], shape=(1,), dtype=bool)
# 180 tf.Tensor([ True], shape=(1,), dtype=bool)
# 181 tf.Tensor([ True], shape=(1,), dtype=bool)
# 182 tf.Tensor([ True], shape=(1,), dtype=bool)
# 183 tf.Tensor([ True], shape=(1,), dtype=bool)
# 184 tf.Tensor([ True], shape=(1,), dtype=bool)
# 185 tf.Tensor([ True], shape=(1,), dtype=bool)
# 186 tf.Tensor([ True], shape=(1,), dtype=bool)
# 187 tf.Tensor([ True], shape=(1,), dtype=bool)
# 188 tf.Tensor([ True], shape=(1,), dtype=bool)
# 189 tf.Tensor([ True], shape=(1,), dtype=bool)
# 190 tf.Tensor([ True], shape=(1,), dtype=bool)
# 191 tf.Tensor([ True], shape=(1,), dtype=bool)
# 192 tf.Tensor([ True], shape=(1,), dtype=bool)
# 193 tf.Tensor([ True], shape=(1,), dtype=bool)
# 194 tf.Tensor([ True], shape=(1,), dtype=bool)
# 195 tf.Tensor([ True], shape=(1,), dtype=bool)
# 196 tf.Tensor([ True], shape=(1,), dtype=bool)
# 197 tf.Tensor([ True], shape=(1,), dtype=bool)
# 198 tf.Tensor([ True], shape=(1,), dtype=bool)
# 199 tf.Tensor([ True], shape=(1,), dtype=bool)
# 200 tf.Tensor([ True], shape=(1,), dtype=bool)
# 201 tf.Tensor([ True], shape=(1,), dtype=bool)
# 202 tf.Tensor([ True], shape=(1,), dtype=bool)
# 203 tf.Tensor([ True], shape=(1,), dtype=bool)
# 204 tf.Tensor([ True], shape=(1,), dtype=bool)
# 205 tf.Tensor([ True], shape=(1,), dtype=bool)
# 206 tf.Tensor([ True], shape=(1,), dtype=bool)
# 207 tf.Tensor([ True], shape=(1,), dtype=bool)
# 208 tf.Tensor([ True], shape=(1,), dtype=bool)
# 209 tf.Tensor([ True], shape=(1,), dtype=bool)
# 210 tf.Tensor([ True], shape=(1,), dtype=bool)
# 211 tf.Tensor([ True], shape=(1,), dtype=bool)
# 212 tf.Tensor([ True], shape=(1,), dtype=bool)
# 213 tf.Tensor([ True], shape=(1,), dtype=bool)
# 214 tf.Tensor([ True], shape=(1,), dtype=bool)
# 215 tf.Tensor([ True], shape=(1,), dtype=bool)
# 216 tf.Tensor([ True], shape=(1,), dtype=bool)
# 217 tf.Tensor([ True], shape=(1,), dtype=bool)
# 218 tf.Tensor([ True], shape=(1,), dtype=bool)
# 219 tf.Tensor([ True], shape=(1,), dtype=bool)
# 220 tf.Tensor([ True], shape=(1,), dtype=bool)
# 221 tf.Tensor([ True], shape=(1,), dtype=bool)
# 222 tf.Tensor([ True], shape=(1,), dtype=bool)
# 223 tf.Tensor([ True], shape=(1,), dtype=bool)
# 224 tf.Tensor([ True], shape=(1,), dtype=bool)
# 225 tf.Tensor([ True], shape=(1,), dtype=bool)
# 226 tf.Tensor([ True], shape=(1,), dtype=bool)
# 227 tf.Tensor([ True], shape=(1,), dtype=bool)
# 228 tf.Tensor([ True], shape=(1,), dtype=bool)
# 229 tf.Tensor([ True], shape=(1,), dtype=bool)
# 230 tf.Tensor([ True], shape=(1,), dtype=bool)
# 231 tf.Tensor([ True], shape=(1,), dtype=bool)
# 232 tf.Tensor([ True], shape=(1,), dtype=bool)
# 233 tf.Tensor([ True], shape=(1,), dtype=bool)
# 234 tf.Tensor([ True], shape=(1,), dtype=bool)
# 235 tf.Tensor([ True], shape=(1,), dtype=bool)
# 236 tf.Tensor([ True], shape=(1,), dtype=bool)
# 237 tf.Tensor([ True], shape=(1,), dtype=bool)
# 238 tf.Tensor([ True], shape=(1,), dtype=bool)
# 239 tf.Tensor([ True], shape=(1,), dtype=bool)
# 240 tf.Tensor([ True], shape=(1,), dtype=bool)
# 241 tf.Tensor([ True], shape=(1,), dtype=bool)
# 242 tf.Tensor([ True], shape=(1,), dtype=bool)
# 243 tf.Tensor([ True], shape=(1,), dtype=bool)
# 244 tf.Tensor([ True], shape=(1,), dtype=bool)
# 245 tf.Tensor([ True], shape=(1,), dtype=bool)
# 246 tf.Tensor([ True], shape=(1,), dtype=bool)
# 247 tf.Tensor([ True], shape=(1,), dtype=bool)
# 248 tf.Tensor([ True], shape=(1,), dtype=bool)
# 249 tf.Tensor([ True], shape=(1,), dtype=bool)
# 250 tf.Tensor([ True], shape=(1,), dtype=bool)
# 251 tf.Tensor([ True], shape=(1,), dtype=bool)
# 252 tf.Tensor([ True], shape=(1,), dtype=bool)
# 253 tf.Tensor([ True], shape=(1,), dtype=bool)
# 254 tf.Tensor([ True], shape=(1,), dtype=bool)
# 255 tf.Tensor([ True], shape=(1,), dtype=bool)
# 256 tf.Tensor([ True], shape=(1,), dtype=bool)
# 257 tf.Tensor([ True], shape=(1,), dtype=bool)
# 258 tf.Tensor([ True], shape=(1,), dtype=bool)
# 259 tf.Tensor([ True], shape=(1,), dtype=bool)
# 260 tf.Tensor([ True], shape=(1,), dtype=bool)
# 261 tf.Tensor([ True], shape=(1,), dtype=bool)
# 262 tf.Tensor([ True], shape=(1,), dtype=bool)
# 263 tf.Tensor([ True], shape=(1,), dtype=bool)
# 264 tf.Tensor([ True], shape=(1,), dtype=bool)
# 265 tf.Tensor([ True], shape=(1,), dtype=bool)
# 266 tf.Tensor([ True], shape=(1,), dtype=bool)
# 267 tf.Tensor([ True], shape=(1,), dtype=bool)
# 268 tf.Tensor([ True], shape=(1,), dtype=bool)
# 269 tf.Tensor([ True], shape=(1,), dtype=bool)
# 270 tf.Tensor([ True], shape=(1,), dtype=bool)
# 271 tf.Tensor([ True], shape=(1,), dtype=bool)
# 272 tf.Tensor([ True], shape=(1,), dtype=bool)
# 273 tf.Tensor([ True], shape=(1,), dtype=bool)
# 274 tf.Tensor([ True], shape=(1,), dtype=bool)
# 275 tf.Tensor([ True], shape=(1,), dtype=bool)
# 276 tf.Tensor([ True], shape=(1,), dtype=bool)
# 277 tf.Tensor([ True], shape=(1,), dtype=bool)
# 278 tf.Tensor([ True], shape=(1,), dtype=bool)
# 279 tf.Tensor([ True], shape=(1,), dtype=bool)
# 280 tf.Tensor([ True], shape=(1,), dtype=bool)
# 281 tf.Tensor([ True], shape=(1,), dtype=bool)
# 282 tf.Tensor([ True], shape=(1,), dtype=bool)
# 283 tf.Tensor([ True], shape=(1,), dtype=bool)
# 284 tf.Tensor([ True], shape=(1,), dtype=bool)
# 285 tf.Tensor([ True], shape=(1,), dtype=bool)
# 286 tf.Tensor([ True], shape=(1,), dtype=bool)
# 287 tf.Tensor([ True], shape=(1,), dtype=bool)
# 288 tf.Tensor([ True], shape=(1,), dtype=bool)
# 289 tf.Tensor([ True], shape=(1,), dtype=bool)
# 290 tf.Tensor([ True], shape=(1,), dtype=bool)
# 291 tf.Tensor([False], shape=(1,), dtype=bool)
# 292 tf.Tensor([ True], shape=(1,), dtype=bool)
# 293 tf.Tensor([ True], shape=(1,), dtype=bool)
# 294 tf.Tensor([ True], shape=(1,), dtype=bool)
# 295 tf.Tensor([ True], shape=(1,), dtype=bool)
# 296 tf.Tensor([ True], shape=(1,), dtype=bool)
# 297 tf.Tensor([ True], shape=(1,), dtype=bool)
# 298 tf.Tensor([ True], shape=(1,), dtype=bool)
# 299 tf.Tensor([ True], shape=(1,), dtype=bool)
# 300 tf.Tensor([ True], shape=(1,), dtype=bool)
# 301 tf.Tensor([ True], shape=(1,), dtype=bool)
# 302 tf.Tensor([ True], shape=(1,), dtype=bool)
# 303 tf.Tensor([ True], shape=(1,), dtype=bool)
# 304 tf.Tensor([ True], shape=(1,), dtype=bool)
# 305 tf.Tensor([ True], shape=(1,), dtype=bool)
# 306 tf.Tensor([ True], shape=(1,), dtype=bool)
# 307 tf.Tensor([ True], shape=(1,), dtype=bool)
# 308 tf.Tensor([ True], shape=(1,), dtype=bool)
# 309 tf.Tensor([ True], shape=(1,), dtype=bool)
# 310 tf.Tensor([ True], shape=(1,), dtype=bool)
# 311 tf.Tensor([ True], shape=(1,), dtype=bool)
# 312 tf.Tensor([ True], shape=(1,), dtype=bool)
# 313 tf.Tensor([ True], shape=(1,), dtype=bool)
# 314 tf.Tensor([ True], shape=(1,), dtype=bool)
# 315 tf.Tensor([ True], shape=(1,), dtype=bool)
# 316 tf.Tensor([ True], shape=(1,), dtype=bool)
# 317 tf.Tensor([ True], shape=(1,), dtype=bool)
# 318 tf.Tensor([ True], shape=(1,), dtype=bool)
# 319 tf.Tensor([ True], shape=(1,), dtype=bool)
# 320 tf.Tensor([ True], shape=(1,), dtype=bool)
# 321 tf.Tensor([False], shape=(1,), dtype=bool)
# 322 tf.Tensor([False], shape=(1,), dtype=bool)
# 323 tf.Tensor([ True], shape=(1,), dtype=bool)
# 324 tf.Tensor([ True], shape=(1,), dtype=bool)
# 325 tf.Tensor([ True], shape=(1,), dtype=bool)
# 326 tf.Tensor([ True], shape=(1,), dtype=bool)
# 327 tf.Tensor([ True], shape=(1,), dtype=bool)
# 328 tf.Tensor([ True], shape=(1,), dtype=bool)
# 329 tf.Tensor([ True], shape=(1,), dtype=bool)
# 330 tf.Tensor([ True], shape=(1,), dtype=bool)
# 331 tf.Tensor([ True], shape=(1,), dtype=bool)
# 332 tf.Tensor([ True], shape=(1,), dtype=bool)
# 333 tf.Tensor([ True], shape=(1,), dtype=bool)
# 334 tf.Tensor([ True], shape=(1,), dtype=bool)
# 335 tf.Tensor([ True], shape=(1,), dtype=bool)
# 336 tf.Tensor([ True], shape=(1,), dtype=bool)
# 337 tf.Tensor([ True], shape=(1,), dtype=bool)
# 338 tf.Tensor([ True], shape=(1,), dtype=bool)
# 339 tf.Tensor([ True], shape=(1,), dtype=bool)
# 340 tf.Tensor([ True], shape=(1,), dtype=bool)
# 341 tf.Tensor([False], shape=(1,), dtype=bool)
# 342 tf.Tensor([ True], shape=(1,), dtype=bool)
# 343 tf.Tensor([ True], shape=(1,), dtype=bool)
# 344 tf.Tensor([ True], shape=(1,), dtype=bool)
# 345 tf.Tensor([ True], shape=(1,), dtype=bool)
# 346 tf.Tensor([ True], shape=(1,), dtype=bool)
# 347 tf.Tensor([ True], shape=(1,), dtype=bool)
# 348 tf.Tensor([ True], shape=(1,), dtype=bool)
# 349 tf.Tensor([ True], shape=(1,), dtype=bool)
# 350 tf.Tensor([ True], shape=(1,), dtype=bool)
# 351 tf.Tensor([ True], shape=(1,), dtype=bool)
# 352 tf.Tensor([ True], shape=(1,), dtype=bool)
# 353 tf.Tensor([ True], shape=(1,), dtype=bool)
# 354 tf.Tensor([ True], shape=(1,), dtype=bool)
# 355 tf.Tensor([ True], shape=(1,), dtype=bool)
# 356 tf.Tensor([ True], shape=(1,), dtype=bool)
# 357 tf.Tensor([ True], shape=(1,), dtype=bool)
# 358 tf.Tensor([ True], shape=(1,), dtype=bool)
# 359 tf.Tensor([ True], shape=(1,), dtype=bool)
# 360 tf.Tensor([ True], shape=(1,), dtype=bool)
# 361 tf.Tensor([ True], shape=(1,), dtype=bool)
# 362 tf.Tensor([ True], shape=(1,), dtype=bool)
# 363 tf.Tensor([ True], shape=(1,), dtype=bool)
# 364 tf.Tensor([ True], shape=(1,), dtype=bool)
# 365 tf.Tensor([ True], shape=(1,), dtype=bool)
# 366 tf.Tensor([ True], shape=(1,), dtype=bool)
# 367 tf.Tensor([ True], shape=(1,), dtype=bool)
# 368 tf.Tensor([ True], shape=(1,), dtype=bool)
# 369 tf.Tensor([ True], shape=(1,), dtype=bool)
# 370 tf.Tensor([ True], shape=(1,), dtype=bool)
# 371 tf.Tensor([ True], shape=(1,), dtype=bool)
# 372 tf.Tensor([ True], shape=(1,), dtype=bool)
# 373 tf.Tensor([ True], shape=(1,), dtype=bool)
# 374 tf.Tensor([ True], shape=(1,), dtype=bool)
# 375 tf.Tensor([ True], shape=(1,), dtype=bool)
# 376 tf.Tensor([ True], shape=(1,), dtype=bool)
# 377 tf.Tensor([ True], shape=(1,), dtype=bool)
# 378 tf.Tensor([ True], shape=(1,), dtype=bool)
# 379 tf.Tensor([ True], shape=(1,), dtype=bool)
# 380 tf.Tensor([ True], shape=(1,), dtype=bool)
# 381 tf.Tensor([ True], shape=(1,), dtype=bool)
# 382 tf.Tensor([ True], shape=(1,), dtype=bool)
# 383 tf.Tensor([ True], shape=(1,), dtype=bool)
# 384 tf.Tensor([ True], shape=(1,), dtype=bool)
# 385 tf.Tensor([ True], shape=(1,), dtype=bool)
# 386 tf.Tensor([ True], shape=(1,), dtype=bool)
# 387 tf.Tensor([ True], shape=(1,), dtype=bool)
# 388 tf.Tensor([ True], shape=(1,), dtype=bool)
# 389 tf.Tensor([ True], shape=(1,), dtype=bool)
# 390 tf.Tensor([ True], shape=(1,), dtype=bool)
# 391 tf.Tensor([ True], shape=(1,), dtype=bool)
# 392 tf.Tensor([ True], shape=(1,), dtype=bool)
# 393 tf.Tensor([ True], shape=(1,), dtype=bool)
# 394 tf.Tensor([ True], shape=(1,), dtype=bool)
# 395 tf.Tensor([ True], shape=(1,), dtype=bool)
# 396 tf.Tensor([ True], shape=(1,), dtype=bool)
# 397 tf.Tensor([ True], shape=(1,), dtype=bool)
# 398 tf.Tensor([ True], shape=(1,), dtype=bool)
# 399 tf.Tensor([ True], shape=(1,), dtype=bool)
# 400 tf.Tensor([ True], shape=(1,), dtype=bool)
# 401 tf.Tensor([ True], shape=(1,), dtype=bool)
# 402 tf.Tensor([ True], shape=(1,), dtype=bool)
# 403 tf.Tensor([ True], shape=(1,), dtype=bool)
# 404 tf.Tensor([ True], shape=(1,), dtype=bool)
# 405 tf.Tensor([ True], shape=(1,), dtype=bool)
# 406 tf.Tensor([ True], shape=(1,), dtype=bool)
# 407 tf.Tensor([ True], shape=(1,), dtype=bool)
# 408 tf.Tensor([ True], shape=(1,), dtype=bool)
# 409 tf.Tensor([ True], shape=(1,), dtype=bool)
# 410 tf.Tensor([ True], shape=(1,), dtype=bool)
# 411 tf.Tensor([ True], shape=(1,), dtype=bool)
# 412 tf.Tensor([ True], shape=(1,), dtype=bool)
# 413 tf.Tensor([ True], shape=(1,), dtype=bool)
# 414 tf.Tensor([ True], shape=(1,), dtype=bool)
# 415 tf.Tensor([ True], shape=(1,), dtype=bool)
# 416 tf.Tensor([ True], shape=(1,), dtype=bool)
# 417 tf.Tensor([ True], shape=(1,), dtype=bool)
# 418 tf.Tensor([ True], shape=(1,), dtype=bool)
# 419 tf.Tensor([ True], shape=(1,), dtype=bool)
# 420 tf.Tensor([ True], shape=(1,), dtype=bool)
# 421 tf.Tensor([ True], shape=(1,), dtype=bool)
# 422 tf.Tensor([ True], shape=(1,), dtype=bool)
# 423 tf.Tensor([ True], shape=(1,), dtype=bool)
# 424 tf.Tensor([ True], shape=(1,), dtype=bool)
# 425 tf.Tensor([ True], shape=(1,), dtype=bool)
# 426 tf.Tensor([ True], shape=(1,), dtype=bool)
# 427 tf.Tensor([ True], shape=(1,), dtype=bool)
# 428 tf.Tensor([ True], shape=(1,), dtype=bool)
# 429 tf.Tensor([ True], shape=(1,), dtype=bool)
# 430 tf.Tensor([ True], shape=(1,), dtype=bool)
# 431 tf.Tensor([ True], shape=(1,), dtype=bool)
# 432 tf.Tensor([ True], shape=(1,), dtype=bool)
# 433 tf.Tensor([ True], shape=(1,), dtype=bool)
# 434 tf.Tensor([ True], shape=(1,), dtype=bool)
# 435 tf.Tensor([ True], shape=(1,), dtype=bool)
# 436 tf.Tensor([ True], shape=(1,), dtype=bool)
# 437 tf.Tensor([ True], shape=(1,), dtype=bool)
# 438 tf.Tensor([ True], shape=(1,), dtype=bool)
# 439 tf.Tensor([ True], shape=(1,), dtype=bool)
# 440 tf.Tensor([ True], shape=(1,), dtype=bool)
# 441 tf.Tensor([ True], shape=(1,), dtype=bool)
# 442 tf.Tensor([ True], shape=(1,), dtype=bool)
# 443 tf.Tensor([ True], shape=(1,), dtype=bool)
# 444 tf.Tensor([ True], shape=(1,), dtype=bool)
# 445 tf.Tensor([ True], shape=(1,), dtype=bool)
# 446 tf.Tensor([False], shape=(1,), dtype=bool)
# 447 tf.Tensor([ True], shape=(1,), dtype=bool)
# 448 tf.Tensor([ True], shape=(1,), dtype=bool)
# 449 tf.Tensor([ True], shape=(1,), dtype=bool)
# 450 tf.Tensor([ True], shape=(1,), dtype=bool)
# 451 tf.Tensor([ True], shape=(1,), dtype=bool)
# 452 tf.Tensor([ True], shape=(1,), dtype=bool)
# 453 tf.Tensor([ True], shape=(1,), dtype=bool)
# 454 tf.Tensor([ True], shape=(1,), dtype=bool)
# 455 tf.Tensor([ True], shape=(1,), dtype=bool)
# 456 tf.Tensor([ True], shape=(1,), dtype=bool)
# 457 tf.Tensor([ True], shape=(1,), dtype=bool)
# 458 tf.Tensor([ True], shape=(1,), dtype=bool)
# 459 tf.Tensor([ True], shape=(1,), dtype=bool)
# 460 tf.Tensor([ True], shape=(1,), dtype=bool)
# 461 tf.Tensor([ True], shape=(1,), dtype=bool)
# 462 tf.Tensor([ True], shape=(1,), dtype=bool)
# 463 tf.Tensor([ True], shape=(1,), dtype=bool)
# 464 tf.Tensor([ True], shape=(1,), dtype=bool)
# 465 tf.Tensor([ True], shape=(1,), dtype=bool)
# 466 tf.Tensor([ True], shape=(1,), dtype=bool)
# 467 tf.Tensor([ True], shape=(1,), dtype=bool)
# 468 tf.Tensor([ True], shape=(1,), dtype=bool)
# 469 tf.Tensor([ True], shape=(1,), dtype=bool)
# 470 tf.Tensor([ True], shape=(1,), dtype=bool)
# 471 tf.Tensor([ True], shape=(1,), dtype=bool)
# 472 tf.Tensor([ True], shape=(1,), dtype=bool)
# 473 tf.Tensor([ True], shape=(1,), dtype=bool)
# 474 tf.Tensor([ True], shape=(1,), dtype=bool)
# 475 tf.Tensor([ True], shape=(1,), dtype=bool)
# 476 tf.Tensor([ True], shape=(1,), dtype=bool)
# 477 tf.Tensor([ True], shape=(1,), dtype=bool)
# 478 tf.Tensor([ True], shape=(1,), dtype=bool)
# 479 tf.Tensor([ True], shape=(1,), dtype=bool)
# 480 tf.Tensor([ True], shape=(1,), dtype=bool)
# 481 tf.Tensor([ True], shape=(1,), dtype=bool)
# 482 tf.Tensor([ True], shape=(1,), dtype=bool)
# 483 tf.Tensor([ True], shape=(1,), dtype=bool)
# 484 tf.Tensor([ True], shape=(1,), dtype=bool)
# 485 tf.Tensor([ True], shape=(1,), dtype=bool)
# 486 tf.Tensor([ True], shape=(1,), dtype=bool)
# 487 tf.Tensor([ True], shape=(1,), dtype=bool)
# 488 tf.Tensor([ True], shape=(1,), dtype=bool)
# 489 tf.Tensor([ True], shape=(1,), dtype=bool)
# 490 tf.Tensor([ True], shape=(1,), dtype=bool)
# 491 tf.Tensor([ True], shape=(1,), dtype=bool)
# 492 tf.Tensor([ True], shape=(1,), dtype=bool)
# 493 tf.Tensor([ True], shape=(1,), dtype=bool)
# 494 tf.Tensor([ True], shape=(1,), dtype=bool)
# 495 tf.Tensor([ True], shape=(1,), dtype=bool)
# 496 tf.Tensor([ True], shape=(1,), dtype=bool)
# 497 tf.Tensor([ True], shape=(1,), dtype=bool)
# 498 tf.Tensor([ True], shape=(1,), dtype=bool)
# 499 tf.Tensor([ True], shape=(1,), dtype=bool)
# 500 tf.Tensor([ True], shape=(1,), dtype=bool)
# 501 tf.Tensor([ True], shape=(1,), dtype=bool)
# 502 tf.Tensor([ True], shape=(1,), dtype=bool)
# 503 tf.Tensor([ True], shape=(1,), dtype=bool)
# 504 tf.Tensor([ True], shape=(1,), dtype=bool)
# 505 tf.Tensor([ True], shape=(1,), dtype=bool)
# 506 tf.Tensor([ True], shape=(1,), dtype=bool)
# 507 tf.Tensor([ True], shape=(1,), dtype=bool)
# 508 tf.Tensor([ True], shape=(1,), dtype=bool)
# 509 tf.Tensor([ True], shape=(1,), dtype=bool)
# 510 tf.Tensor([ True], shape=(1,), dtype=bool)
# 511 tf.Tensor([ True], shape=(1,), dtype=bool)
# 512 tf.Tensor([ True], shape=(1,), dtype=bool)
# 513 tf.Tensor([ True], shape=(1,), dtype=bool)
# 514 tf.Tensor([ True], shape=(1,), dtype=bool)
# 515 tf.Tensor([ True], shape=(1,), dtype=bool)
# 516 tf.Tensor([ True], shape=(1,), dtype=bool)
# 517 tf.Tensor([ True], shape=(1,), dtype=bool)
# 518 tf.Tensor([ True], shape=(1,), dtype=bool)
# 519 tf.Tensor([ True], shape=(1,), dtype=bool)
# 520 tf.Tensor([ True], shape=(1,), dtype=bool)
# 521 tf.Tensor([ True], shape=(1,), dtype=bool)
# 522 tf.Tensor([ True], shape=(1,), dtype=bool)
# 523 tf.Tensor([ True], shape=(1,), dtype=bool)
# 524 tf.Tensor([ True], shape=(1,), dtype=bool)
# 525 tf.Tensor([ True], shape=(1,), dtype=bool)
# 526 tf.Tensor([ True], shape=(1,), dtype=bool)
# 527 tf.Tensor([ True], shape=(1,), dtype=bool)
# 528 tf.Tensor([ True], shape=(1,), dtype=bool)
# 529 tf.Tensor([ True], shape=(1,), dtype=bool)
# 530 tf.Tensor([ True], shape=(1,), dtype=bool)
# 531 tf.Tensor([ True], shape=(1,), dtype=bool)
# 532 tf.Tensor([ True], shape=(1,), dtype=bool)
# 533 tf.Tensor([ True], shape=(1,), dtype=bool)
# 534 tf.Tensor([ True], shape=(1,), dtype=bool)
# 535 tf.Tensor([ True], shape=(1,), dtype=bool)
# 536 tf.Tensor([ True], shape=(1,), dtype=bool)
# 537 tf.Tensor([ True], shape=(1,), dtype=bool)
# 538 tf.Tensor([ True], shape=(1,), dtype=bool)
# 539 tf.Tensor([ True], shape=(1,), dtype=bool)
# 540 tf.Tensor([ True], shape=(1,), dtype=bool)
# 541 tf.Tensor([ True], shape=(1,), dtype=bool)
# 542 tf.Tensor([ True], shape=(1,), dtype=bool)
# 543 tf.Tensor([ True], shape=(1,), dtype=bool)
# 544 tf.Tensor([ True], shape=(1,), dtype=bool)
# 545 tf.Tensor([ True], shape=(1,), dtype=bool)
# 546 tf.Tensor([ True], shape=(1,), dtype=bool)
# 547 tf.Tensor([ True], shape=(1,), dtype=bool)
# 548 tf.Tensor([ True], shape=(1,), dtype=bool)
# 549 tf.Tensor([ True], shape=(1,), dtype=bool)
# 550 tf.Tensor([ True], shape=(1,), dtype=bool)
# 551 tf.Tensor([ True], shape=(1,), dtype=bool)
# 552 tf.Tensor([ True], shape=(1,), dtype=bool)
# 553 tf.Tensor([ True], shape=(1,), dtype=bool)
# 554 tf.Tensor([ True], shape=(1,), dtype=bool)
# 555 tf.Tensor([ True], shape=(1,), dtype=bool)
# 556 tf.Tensor([ True], shape=(1,), dtype=bool)
# 557 tf.Tensor([ True], shape=(1,), dtype=bool)
# 558 tf.Tensor([ True], shape=(1,), dtype=bool)
# 559 tf.Tensor([ True], shape=(1,), dtype=bool)
# 560 tf.Tensor([ True], shape=(1,), dtype=bool)
# 561 tf.Tensor([ True], shape=(1,), dtype=bool)
# 562 tf.Tensor([ True], shape=(1,), dtype=bool)
# 563 tf.Tensor([ True], shape=(1,), dtype=bool)
# 564 tf.Tensor([ True], shape=(1,), dtype=bool)
# 565 tf.Tensor([ True], shape=(1,), dtype=bool)
# 566 tf.Tensor([ True], shape=(1,), dtype=bool)
# 567 tf.Tensor([ True], shape=(1,), dtype=bool)
# 568 tf.Tensor([ True], shape=(1,), dtype=bool)
# 569 tf.Tensor([ True], shape=(1,), dtype=bool)
# 570 tf.Tensor([ True], shape=(1,), dtype=bool)
# 571 tf.Tensor([ True], shape=(1,), dtype=bool)
# 572 tf.Tensor([ True], shape=(1,), dtype=bool)
# 573 tf.Tensor([ True], shape=(1,), dtype=bool)
# 574 tf.Tensor([ True], shape=(1,), dtype=bool)
# 575 tf.Tensor([ True], shape=(1,), dtype=bool)
# 576 tf.Tensor([ True], shape=(1,), dtype=bool)
# 577 tf.Tensor([ True], shape=(1,), dtype=bool)
# 578 tf.Tensor([ True], shape=(1,), dtype=bool)
# 579 tf.Tensor([ True], shape=(1,), dtype=bool)
# 580 tf.Tensor([ True], shape=(1,), dtype=bool)
# 581 tf.Tensor([ True], shape=(1,), dtype=bool)
# 582 tf.Tensor([ True], shape=(1,), dtype=bool)
# 583 tf.Tensor([False], shape=(1,), dtype=bool)
# 584 tf.Tensor([ True], shape=(1,), dtype=bool)
# 585 tf.Tensor([ True], shape=(1,), dtype=bool)
# 586 tf.Tensor([ True], shape=(1,), dtype=bool)
# 587 tf.Tensor([ True], shape=(1,), dtype=bool)
# 588 tf.Tensor([ True], shape=(1,), dtype=bool)
# 589 tf.Tensor([ True], shape=(1,), dtype=bool)
# 590 tf.Tensor([ True], shape=(1,), dtype=bool)
# 591 tf.Tensor([ True], shape=(1,), dtype=bool)
# 592 tf.Tensor([ True], shape=(1,), dtype=bool)
# 593 tf.Tensor([ True], shape=(1,), dtype=bool)
# 594 tf.Tensor([ True], shape=(1,), dtype=bool)
# 595 tf.Tensor([ True], shape=(1,), dtype=bool)
# 596 tf.Tensor([ True], shape=(1,), dtype=bool)
# 597 tf.Tensor([ True], shape=(1,), dtype=bool)
# 598 tf.Tensor([ True], shape=(1,), dtype=bool)
# 599 tf.Tensor([ True], shape=(1,), dtype=bool)
# 600 tf.Tensor([ True], shape=(1,), dtype=bool)
# 601 tf.Tensor([ True], shape=(1,), dtype=bool)
# 602 tf.Tensor([ True], shape=(1,), dtype=bool)
# 603 tf.Tensor([ True], shape=(1,), dtype=bool)
# 604 tf.Tensor([False], shape=(1,), dtype=bool)
# 605 tf.Tensor([ True], shape=(1,), dtype=bool)
# 606 tf.Tensor([ True], shape=(1,), dtype=bool)
# 607 tf.Tensor([ True], shape=(1,), dtype=bool)
# 608 tf.Tensor([ True], shape=(1,), dtype=bool)
# 609 tf.Tensor([ True], shape=(1,), dtype=bool)
# 610 tf.Tensor([ True], shape=(1,), dtype=bool)
# 611 tf.Tensor([ True], shape=(1,), dtype=bool)
# 612 tf.Tensor([ True], shape=(1,), dtype=bool)
# 613 tf.Tensor([ True], shape=(1,), dtype=bool)
# 614 tf.Tensor([ True], shape=(1,), dtype=bool)
# 615 tf.Tensor([ True], shape=(1,), dtype=bool)
# 616 tf.Tensor([ True], shape=(1,), dtype=bool)
# 617 tf.Tensor([ True], shape=(1,), dtype=bool)
# 618 tf.Tensor([ True], shape=(1,), dtype=bool)
# 619 tf.Tensor([ True], shape=(1,), dtype=bool)
# 620 tf.Tensor([ True], shape=(1,), dtype=bool)
# 621 tf.Tensor([ True], shape=(1,), dtype=bool)
# 622 tf.Tensor([ True], shape=(1,), dtype=bool)
# 623 tf.Tensor([ True], shape=(1,), dtype=bool)
# 624 tf.Tensor([ True], shape=(1,), dtype=bool)
# 625 tf.Tensor([ True], shape=(1,), dtype=bool)
# 626 tf.Tensor([False], shape=(1,), dtype=bool)
# 627 tf.Tensor([ True], shape=(1,), dtype=bool)
# 628 tf.Tensor([ True], shape=(1,), dtype=bool)
# 629 tf.Tensor([ True], shape=(1,), dtype=bool)
# 630 tf.Tensor([ True], shape=(1,), dtype=bool)
# 631 tf.Tensor([ True], shape=(1,), dtype=bool)
# 632 tf.Tensor([ True], shape=(1,), dtype=bool)
# 633 tf.Tensor([ True], shape=(1,), dtype=bool)
# 634 tf.Tensor([ True], shape=(1,), dtype=bool)
# 635 tf.Tensor([ True], shape=(1,), dtype=bool)
# 636 tf.Tensor([ True], shape=(1,), dtype=bool)
# 637 tf.Tensor([ True], shape=(1,), dtype=bool)
# 638 tf.Tensor([ True], shape=(1,), dtype=bool)
# 639 tf.Tensor([ True], shape=(1,), dtype=bool)
# 640 tf.Tensor([ True], shape=(1,), dtype=bool)
# 641 tf.Tensor([ True], shape=(1,), dtype=bool)
# 642 tf.Tensor([ True], shape=(1,), dtype=bool)
# 643 tf.Tensor([ True], shape=(1,), dtype=bool)
# 644 tf.Tensor([ True], shape=(1,), dtype=bool)
# 645 tf.Tensor([ True], shape=(1,), dtype=bool)
# 646 tf.Tensor([ True], shape=(1,), dtype=bool)
# 647 tf.Tensor([ True], shape=(1,), dtype=bool)
# 648 tf.Tensor([ True], shape=(1,), dtype=bool)
# 649 tf.Tensor([ True], shape=(1,), dtype=bool)
# 650 tf.Tensor([ True], shape=(1,), dtype=bool)
# 651 tf.Tensor([ True], shape=(1,), dtype=bool)
# 652 tf.Tensor([ True], shape=(1,), dtype=bool)
# 653 tf.Tensor([ True], shape=(1,), dtype=bool)
# 654 tf.Tensor([ True], shape=(1,), dtype=bool)
# 655 tf.Tensor([ True], shape=(1,), dtype=bool)
# 656 tf.Tensor([ True], shape=(1,), dtype=bool)
# 657 tf.Tensor([ True], shape=(1,), dtype=bool)
# 658 tf.Tensor([ True], shape=(1,), dtype=bool)
# 659 tf.Tensor([ True], shape=(1,), dtype=bool)
# 660 tf.Tensor([False], shape=(1,), dtype=bool)
# 661 tf.Tensor([ True], shape=(1,), dtype=bool)
# 662 tf.Tensor([ True], shape=(1,), dtype=bool)
# 663 tf.Tensor([ True], shape=(1,), dtype=bool)
# 664 tf.Tensor([ True], shape=(1,), dtype=bool)
# 665 tf.Tensor([ True], shape=(1,), dtype=bool)
# 666 tf.Tensor([ True], shape=(1,), dtype=bool)
# 667 tf.Tensor([ True], shape=(1,), dtype=bool)
# 668 tf.Tensor([ True], shape=(1,), dtype=bool)
# 669 tf.Tensor([ True], shape=(1,), dtype=bool)
# 670 tf.Tensor([ True], shape=(1,), dtype=bool)
# 671 tf.Tensor([ True], shape=(1,), dtype=bool)
# 672 tf.Tensor([ True], shape=(1,), dtype=bool)
# 673 tf.Tensor([ True], shape=(1,), dtype=bool)
# 674 tf.Tensor([ True], shape=(1,), dtype=bool)
# 675 tf.Tensor([False], shape=(1,), dtype=bool)
# 676 tf.Tensor([ True], shape=(1,), dtype=bool)
# 677 tf.Tensor([ True], shape=(1,), dtype=bool)
# 678 tf.Tensor([ True], shape=(1,), dtype=bool)
# 679 tf.Tensor([ True], shape=(1,), dtype=bool)
# 680 tf.Tensor([ True], shape=(1,), dtype=bool)
# 681 tf.Tensor([ True], shape=(1,), dtype=bool)
# 682 tf.Tensor([ True], shape=(1,), dtype=bool)
# 683 tf.Tensor([ True], shape=(1,), dtype=bool)
# 684 tf.Tensor([ True], shape=(1,), dtype=bool)
# 685 tf.Tensor([ True], shape=(1,), dtype=bool)
# 686 tf.Tensor([ True], shape=(1,), dtype=bool)
# 687 tf.Tensor([ True], shape=(1,), dtype=bool)
# 688 tf.Tensor([ True], shape=(1,), dtype=bool)
# 689 tf.Tensor([ True], shape=(1,), dtype=bool)
# 690 tf.Tensor([ True], shape=(1,), dtype=bool)
# 691 tf.Tensor([ True], shape=(1,), dtype=bool)
# 692 tf.Tensor([False], shape=(1,), dtype=bool)
# 693 tf.Tensor([ True], shape=(1,), dtype=bool)
# 694 tf.Tensor([ True], shape=(1,), dtype=bool)
# 695 tf.Tensor([ True], shape=(1,), dtype=bool)
# 696 tf.Tensor([ True], shape=(1,), dtype=bool)
# 697 tf.Tensor([ True], shape=(1,), dtype=bool)
# 698 tf.Tensor([ True], shape=(1,), dtype=bool)
# 699 tf.Tensor([ True], shape=(1,), dtype=bool)
# 700 tf.Tensor([ True], shape=(1,), dtype=bool)
# 701 tf.Tensor([ True], shape=(1,), dtype=bool)
# 702 tf.Tensor([ True], shape=(1,), dtype=bool)
# 703 tf.Tensor([ True], shape=(1,), dtype=bool)
# 704 tf.Tensor([ True], shape=(1,), dtype=bool)
# 705 tf.Tensor([ True], shape=(1,), dtype=bool)
# 706 tf.Tensor([ True], shape=(1,), dtype=bool)
# 707 tf.Tensor([ True], shape=(1,), dtype=bool)
# 708 tf.Tensor([ True], shape=(1,), dtype=bool)
# 709 tf.Tensor([ True], shape=(1,), dtype=bool)
# 710 tf.Tensor([ True], shape=(1,), dtype=bool)
# 711 tf.Tensor([ True], shape=(1,), dtype=bool)
# 712 tf.Tensor([ True], shape=(1,), dtype=bool)
# 713 tf.Tensor([ True], shape=(1,), dtype=bool)
# 714 tf.Tensor([ True], shape=(1,), dtype=bool)
# 715 tf.Tensor([ True], shape=(1,), dtype=bool)
# 716 tf.Tensor([ True], shape=(1,), dtype=bool)
# 717 tf.Tensor([False], shape=(1,), dtype=bool)
# 718 tf.Tensor([ True], shape=(1,), dtype=bool)
# 719 tf.Tensor([ True], shape=(1,), dtype=bool)
# 720 tf.Tensor([ True], shape=(1,), dtype=bool)
# 721 tf.Tensor([ True], shape=(1,), dtype=bool)
# 722 tf.Tensor([ True], shape=(1,), dtype=bool)
# 723 tf.Tensor([ True], shape=(1,), dtype=bool)
# 724 tf.Tensor([ True], shape=(1,), dtype=bool)
# 725 tf.Tensor([ True], shape=(1,), dtype=bool)
# 726 tf.Tensor([ True], shape=(1,), dtype=bool)
# 727 tf.Tensor([ True], shape=(1,), dtype=bool)
# 728 tf.Tensor([ True], shape=(1,), dtype=bool)
# 729 tf.Tensor([ True], shape=(1,), dtype=bool)
# 730 tf.Tensor([ True], shape=(1,), dtype=bool)
# 731 tf.Tensor([ True], shape=(1,), dtype=bool)
# 732 tf.Tensor([ True], shape=(1,), dtype=bool)
# 733 tf.Tensor([ True], shape=(1,), dtype=bool)
# 734 tf.Tensor([ True], shape=(1,), dtype=bool)
# 735 tf.Tensor([ True], shape=(1,), dtype=bool)
# 736 tf.Tensor([ True], shape=(1,), dtype=bool)
# 737 tf.Tensor([ True], shape=(1,), dtype=bool)
# 738 tf.Tensor([ True], shape=(1,), dtype=bool)
# 739 tf.Tensor([ True], shape=(1,), dtype=bool)
# 740 tf.Tensor([ True], shape=(1,), dtype=bool)
# 741 tf.Tensor([False], shape=(1,), dtype=bool)
# 742 tf.Tensor([ True], shape=(1,), dtype=bool)
# 743 tf.Tensor([ True], shape=(1,), dtype=bool)
# 744 tf.Tensor([ True], shape=(1,), dtype=bool)
# 745 tf.Tensor([ True], shape=(1,), dtype=bool)
# 746 tf.Tensor([ True], shape=(1,), dtype=bool)
# 747 tf.Tensor([ True], shape=(1,), dtype=bool)
# 748 tf.Tensor([ True], shape=(1,), dtype=bool)
# 749 tf.Tensor([ True], shape=(1,), dtype=bool)
# 750 tf.Tensor([ True], shape=(1,), dtype=bool)
# 751 tf.Tensor([ True], shape=(1,), dtype=bool)
# 752 tf.Tensor([ True], shape=(1,), dtype=bool)
# 753 tf.Tensor([ True], shape=(1,), dtype=bool)
# 754 tf.Tensor([ True], shape=(1,), dtype=bool)
# 755 tf.Tensor([ True], shape=(1,), dtype=bool)
# 756 tf.Tensor([ True], shape=(1,), dtype=bool)
# 757 tf.Tensor([ True], shape=(1,), dtype=bool)
# 758 tf.Tensor([ True], shape=(1,), dtype=bool)
# 759 tf.Tensor([ True], shape=(1,), dtype=bool)
# 760 tf.Tensor([ True], shape=(1,), dtype=bool)
# 761 tf.Tensor([ True], shape=(1,), dtype=bool)
# 762 tf.Tensor([ True], shape=(1,), dtype=bool)
# 763 tf.Tensor([ True], shape=(1,), dtype=bool)
# 764 tf.Tensor([ True], shape=(1,), dtype=bool)
# 765 tf.Tensor([ True], shape=(1,), dtype=bool)
# 766 tf.Tensor([ True], shape=(1,), dtype=bool)
# 767 tf.Tensor([ True], shape=(1,), dtype=bool)
# 768 tf.Tensor([ True], shape=(1,), dtype=bool)
# 769 tf.Tensor([ True], shape=(1,), dtype=bool)
# 770 tf.Tensor([ True], shape=(1,), dtype=bool)
# 771 tf.Tensor([ True], shape=(1,), dtype=bool)
# 772 tf.Tensor([ True], shape=(1,), dtype=bool)
# 773 tf.Tensor([ True], shape=(1,), dtype=bool)
# 774 tf.Tensor([ True], shape=(1,), dtype=bool)
# 775 tf.Tensor([ True], shape=(1,), dtype=bool)
# 776 tf.Tensor([ True], shape=(1,), dtype=bool)
# 777 tf.Tensor([ True], shape=(1,), dtype=bool)
# 778 tf.Tensor([ True], shape=(1,), dtype=bool)
# 779 tf.Tensor([ True], shape=(1,), dtype=bool)
# 780 tf.Tensor([ True], shape=(1,), dtype=bool)
# 781 tf.Tensor([ True], shape=(1,), dtype=bool)
# 782 tf.Tensor([ True], shape=(1,), dtype=bool)
# 783 tf.Tensor([ True], shape=(1,), dtype=bool)
# 784 tf.Tensor([ True], shape=(1,), dtype=bool)
# 785 tf.Tensor([ True], shape=(1,), dtype=bool)
# 786 tf.Tensor([ True], shape=(1,), dtype=bool)
# 787 tf.Tensor([ True], shape=(1,), dtype=bool)
# 788 tf.Tensor([ True], shape=(1,), dtype=bool)
# 789 tf.Tensor([ True], shape=(1,), dtype=bool)
# 790 tf.Tensor([ True], shape=(1,), dtype=bool)
# 791 tf.Tensor([ True], shape=(1,), dtype=bool)
# 792 tf.Tensor([ True], shape=(1,), dtype=bool)
# 793 tf.Tensor([ True], shape=(1,), dtype=bool)
# 794 tf.Tensor([ True], shape=(1,), dtype=bool)
# 795 tf.Tensor([ True], shape=(1,), dtype=bool)
# 796 tf.Tensor([ True], shape=(1,), dtype=bool)
# 797 tf.Tensor([ True], shape=(1,), dtype=bool)
# 798 tf.Tensor([ True], shape=(1,), dtype=bool)
# 799 tf.Tensor([ True], shape=(1,), dtype=bool)
# 800 tf.Tensor([ True], shape=(1,), dtype=bool)
# 801 tf.Tensor([ True], shape=(1,), dtype=bool)
# 802 tf.Tensor([ True], shape=(1,), dtype=bool)
# 803 tf.Tensor([ True], shape=(1,), dtype=bool)
# 804 tf.Tensor([ True], shape=(1,), dtype=bool)
# 805 tf.Tensor([False], shape=(1,), dtype=bool)
# 806 tf.Tensor([ True], shape=(1,), dtype=bool)
# 807 tf.Tensor([ True], shape=(1,), dtype=bool)
# 808 tf.Tensor([ True], shape=(1,), dtype=bool)
# 809 tf.Tensor([ True], shape=(1,), dtype=bool)
# 810 tf.Tensor([ True], shape=(1,), dtype=bool)
# 811 tf.Tensor([ True], shape=(1,), dtype=bool)
# 812 tf.Tensor([ True], shape=(1,), dtype=bool)
# 813 tf.Tensor([ True], shape=(1,), dtype=bool)
# 814 tf.Tensor([ True], shape=(1,), dtype=bool)
# 815 tf.Tensor([ True], shape=(1,), dtype=bool)
# 816 tf.Tensor([ True], shape=(1,), dtype=bool)
# 817 tf.Tensor([ True], shape=(1,), dtype=bool)
# 818 tf.Tensor([ True], shape=(1,), dtype=bool)
# 819 tf.Tensor([ True], shape=(1,), dtype=bool)
# 820 tf.Tensor([ True], shape=(1,), dtype=bool)
# 821 tf.Tensor([ True], shape=(1,), dtype=bool)
# 822 tf.Tensor([ True], shape=(1,), dtype=bool)
# 823 tf.Tensor([ True], shape=(1,), dtype=bool)
# 824 tf.Tensor([ True], shape=(1,), dtype=bool)
# 825 tf.Tensor([ True], shape=(1,), dtype=bool)
# 826 tf.Tensor([ True], shape=(1,), dtype=bool)
# 827 tf.Tensor([ True], shape=(1,), dtype=bool)
# 828 tf.Tensor([ True], shape=(1,), dtype=bool)
# 829 tf.Tensor([ True], shape=(1,), dtype=bool)
# 830 tf.Tensor([ True], shape=(1,), dtype=bool)
# 831 tf.Tensor([ True], shape=(1,), dtype=bool)
# 832 tf.Tensor([ True], shape=(1,), dtype=bool)
# 833 tf.Tensor([ True], shape=(1,), dtype=bool)
# 834 tf.Tensor([ True], shape=(1,), dtype=bool)
# 835 tf.Tensor([ True], shape=(1,), dtype=bool)
# 836 tf.Tensor([ True], shape=(1,), dtype=bool)
# 837 tf.Tensor([ True], shape=(1,), dtype=bool)
# 838 tf.Tensor([ True], shape=(1,), dtype=bool)
# 839 tf.Tensor([ True], shape=(1,), dtype=bool)
# 840 tf.Tensor([ True], shape=(1,), dtype=bool)
# 841 tf.Tensor([ True], shape=(1,), dtype=bool)
# 842 tf.Tensor([ True], shape=(1,), dtype=bool)
# 843 tf.Tensor([ True], shape=(1,), dtype=bool)
# 844 tf.Tensor([ True], shape=(1,), dtype=bool)
# 845 tf.Tensor([False], shape=(1,), dtype=bool)
# 846 tf.Tensor([ True], shape=(1,), dtype=bool)
# 847 tf.Tensor([ True], shape=(1,), dtype=bool)
# 848 tf.Tensor([ True], shape=(1,), dtype=bool)
# 849 tf.Tensor([ True], shape=(1,), dtype=bool)
# 850 tf.Tensor([ True], shape=(1,), dtype=bool)
# 851 tf.Tensor([ True], shape=(1,), dtype=bool)
# 852 tf.Tensor([ True], shape=(1,), dtype=bool)
# 853 tf.Tensor([ True], shape=(1,), dtype=bool)
# 854 tf.Tensor([ True], shape=(1,), dtype=bool)
# 855 tf.Tensor([ True], shape=(1,), dtype=bool)
# 856 tf.Tensor([ True], shape=(1,), dtype=bool)
# 857 tf.Tensor([ True], shape=(1,), dtype=bool)
# 858 tf.Tensor([ True], shape=(1,), dtype=bool)
# 859 tf.Tensor([ True], shape=(1,), dtype=bool)
# 860 tf.Tensor([ True], shape=(1,), dtype=bool)
# 861 tf.Tensor([ True], shape=(1,), dtype=bool)
# 862 tf.Tensor([ True], shape=(1,), dtype=bool)
# 863 tf.Tensor([ True], shape=(1,), dtype=bool)
# 864 tf.Tensor([ True], shape=(1,), dtype=bool)
# 865 tf.Tensor([ True], shape=(1,), dtype=bool)
# 866 tf.Tensor([ True], shape=(1,), dtype=bool)
# 867 tf.Tensor([ True], shape=(1,), dtype=bool)
# 868 tf.Tensor([ True], shape=(1,), dtype=bool)
# 869 tf.Tensor([ True], shape=(1,), dtype=bool)
# 870 tf.Tensor([ True], shape=(1,), dtype=bool)
# 871 tf.Tensor([ True], shape=(1,), dtype=bool)
# 872 tf.Tensor([ True], shape=(1,), dtype=bool)
# 873 tf.Tensor([ True], shape=(1,), dtype=bool)
# 874 tf.Tensor([ True], shape=(1,), dtype=bool)
# 875 tf.Tensor([ True], shape=(1,), dtype=bool)
# 876 tf.Tensor([ True], shape=(1,), dtype=bool)
# 877 tf.Tensor([ True], shape=(1,), dtype=bool)
# 878 tf.Tensor([ True], shape=(1,), dtype=bool)
# 879 tf.Tensor([ True], shape=(1,), dtype=bool)
# 880 tf.Tensor([ True], shape=(1,), dtype=bool)
# 881 tf.Tensor([ True], shape=(1,), dtype=bool)
# 882 tf.Tensor([ True], shape=(1,), dtype=bool)
# 883 tf.Tensor([ True], shape=(1,), dtype=bool)
# 884 tf.Tensor([ True], shape=(1,), dtype=bool)
# 885 tf.Tensor([ True], shape=(1,), dtype=bool)
# 886 tf.Tensor([ True], shape=(1,), dtype=bool)
# 887 tf.Tensor([ True], shape=(1,), dtype=bool)
# 888 tf.Tensor([ True], shape=(1,), dtype=bool)
# 889 tf.Tensor([ True], shape=(1,), dtype=bool)
# 890 tf.Tensor([ True], shape=(1,), dtype=bool)
# 891 tf.Tensor([ True], shape=(1,), dtype=bool)
# 892 tf.Tensor([ True], shape=(1,), dtype=bool)
# 893 tf.Tensor([ True], shape=(1,), dtype=bool)
# 894 tf.Tensor([ True], shape=(1,), dtype=bool)
# 895 tf.Tensor([ True], shape=(1,), dtype=bool)
# 896 tf.Tensor([ True], shape=(1,), dtype=bool)
# 897 tf.Tensor([ True], shape=(1,), dtype=bool)
# 898 tf.Tensor([ True], shape=(1,), dtype=bool)
# 899 tf.Tensor([ True], shape=(1,), dtype=bool)
# 900 tf.Tensor([ True], shape=(1,), dtype=bool)
# 901 tf.Tensor([ True], shape=(1,), dtype=bool)
# 902 tf.Tensor([ True], shape=(1,), dtype=bool)
# 903 tf.Tensor([ True], shape=(1,), dtype=bool)
# 904 tf.Tensor([ True], shape=(1,), dtype=bool)
# 905 tf.Tensor([ True], shape=(1,), dtype=bool)
# 906 tf.Tensor([ True], shape=(1,), dtype=bool)
# 907 tf.Tensor([ True], shape=(1,), dtype=bool)
# 908 tf.Tensor([ True], shape=(1,), dtype=bool)
# 909 tf.Tensor([ True], shape=(1,), dtype=bool)
# 910 tf.Tensor([ True], shape=(1,), dtype=bool)
# 911 tf.Tensor([ True], shape=(1,), dtype=bool)
# 912 tf.Tensor([ True], shape=(1,), dtype=bool)
# 913 tf.Tensor([ True], shape=(1,), dtype=bool)
# 914 tf.Tensor([ True], shape=(1,), dtype=bool)
# 915 tf.Tensor([ True], shape=(1,), dtype=bool)
# 916 tf.Tensor([ True], shape=(1,), dtype=bool)
# 917 tf.Tensor([ True], shape=(1,), dtype=bool)
# 918 tf.Tensor([ True], shape=(1,), dtype=bool)
# 919 tf.Tensor([ True], shape=(1,), dtype=bool)
# 920 tf.Tensor([ True], shape=(1,), dtype=bool)
# 921 tf.Tensor([ True], shape=(1,), dtype=bool)
# 922 tf.Tensor([ True], shape=(1,), dtype=bool)
# 923 tf.Tensor([ True], shape=(1,), dtype=bool)
# 924 tf.Tensor([ True], shape=(1,), dtype=bool)
# 925 tf.Tensor([False], shape=(1,), dtype=bool)
# 926 tf.Tensor([ True], shape=(1,), dtype=bool)
# 927 tf.Tensor([ True], shape=(1,), dtype=bool)
# 928 tf.Tensor([ True], shape=(1,), dtype=bool)
# 929 tf.Tensor([ True], shape=(1,), dtype=bool)
# 930 tf.Tensor([ True], shape=(1,), dtype=bool)
# 931 tf.Tensor([ True], shape=(1,), dtype=bool)
# 932 tf.Tensor([ True], shape=(1,), dtype=bool)
# 933 tf.Tensor([ True], shape=(1,), dtype=bool)
# 934 tf.Tensor([ True], shape=(1,), dtype=bool)
# 935 tf.Tensor([ True], shape=(1,), dtype=bool)
# 936 tf.Tensor([ True], shape=(1,), dtype=bool)
# 937 tf.Tensor([ True], shape=(1,), dtype=bool)
# 938 tf.Tensor([ True], shape=(1,), dtype=bool)
# 939 tf.Tensor([False], shape=(1,), dtype=bool)
# 940 tf.Tensor([ True], shape=(1,), dtype=bool)
# 941 tf.Tensor([ True], shape=(1,), dtype=bool)
# 942 tf.Tensor([ True], shape=(1,), dtype=bool)
# 943 tf.Tensor([ True], shape=(1,), dtype=bool)
# 944 tf.Tensor([ True], shape=(1,), dtype=bool)
# 945 tf.Tensor([ True], shape=(1,), dtype=bool)
# 946 tf.Tensor([ True], shape=(1,), dtype=bool)
# 947 tf.Tensor([ True], shape=(1,), dtype=bool)
# 948 tf.Tensor([False], shape=(1,), dtype=bool)
# 949 tf.Tensor([ True], shape=(1,), dtype=bool)
# 950 tf.Tensor([ True], shape=(1,), dtype=bool)
# 951 tf.Tensor([ True], shape=(1,), dtype=bool)
# 952 tf.Tensor([ True], shape=(1,), dtype=bool)
# 953 tf.Tensor([ True], shape=(1,), dtype=bool)
# 954 tf.Tensor([ True], shape=(1,), dtype=bool)
# 955 tf.Tensor([ True], shape=(1,), dtype=bool)
# 956 tf.Tensor([ True], shape=(1,), dtype=bool)
# 957 tf.Tensor([ True], shape=(1,), dtype=bool)
# 958 tf.Tensor([ True], shape=(1,), dtype=bool)
# 959 tf.Tensor([ True], shape=(1,), dtype=bool)
# 960 tf.Tensor([ True], shape=(1,), dtype=bool)
# 961 tf.Tensor([ True], shape=(1,), dtype=bool)
# 962 tf.Tensor([ True], shape=(1,), dtype=bool)
# 963 tf.Tensor([ True], shape=(1,), dtype=bool)
# 964 tf.Tensor([ True], shape=(1,), dtype=bool)
# 965 tf.Tensor([ True], shape=(1,), dtype=bool)
# 966 tf.Tensor([ True], shape=(1,), dtype=bool)
# 967 tf.Tensor([ True], shape=(1,), dtype=bool)
# 968 tf.Tensor([ True], shape=(1,), dtype=bool)
# 969 tf.Tensor([ True], shape=(1,), dtype=bool)
# 970 tf.Tensor([ True], shape=(1,), dtype=bool)
# 971 tf.Tensor([ True], shape=(1,), dtype=bool)
# 972 tf.Tensor([ True], shape=(1,), dtype=bool)
# 973 tf.Tensor([ True], shape=(1,), dtype=bool)
# 974 tf.Tensor([ True], shape=(1,), dtype=bool)
# 975 tf.Tensor([ True], shape=(1,), dtype=bool)
# 976 tf.Tensor([ True], shape=(1,), dtype=bool)
# 977 tf.Tensor([ True], shape=(1,), dtype=bool)
# 978 tf.Tensor([ True], shape=(1,), dtype=bool)
# 979 tf.Tensor([ True], shape=(1,), dtype=bool)
# 980 tf.Tensor([ True], shape=(1,), dtype=bool)
# 981 tf.Tensor([ True], shape=(1,), dtype=bool)
# 982 tf.Tensor([ True], shape=(1,), dtype=bool)
# 983 tf.Tensor([ True], shape=(1,), dtype=bool)
# 984 tf.Tensor([ True], shape=(1,), dtype=bool)
# 985 tf.Tensor([ True], shape=(1,), dtype=bool)
# 986 tf.Tensor([ True], shape=(1,), dtype=bool)
# 987 tf.Tensor([ True], shape=(1,), dtype=bool)
# 988 tf.Tensor([ True], shape=(1,), dtype=bool)
# 989 tf.Tensor([ True], shape=(1,), dtype=bool)
# 990 tf.Tensor([ True], shape=(1,), dtype=bool)
# 991 tf.Tensor([ True], shape=(1,), dtype=bool)
# 992 tf.Tensor([ True], shape=(1,), dtype=bool)
# 993 tf.Tensor([ True], shape=(1,), dtype=bool)
# 994 tf.Tensor([ True], shape=(1,), dtype=bool)
# 995 tf.Tensor([ True], shape=(1,), dtype=bool)
# 996 tf.Tensor([ True], shape=(1,), dtype=bool)
# 997 tf.Tensor([ True], shape=(1,), dtype=bool)
# 998 tf.Tensor([ True], shape=(1,), dtype=bool)
# 999 tf.Tensor([ True], shape=(1,), dtype=bool)
# 1000 tf.Tensor([ True], shape=(1,), dtype=bool)
# 1001 tf.Tensor([ True], shape=(1,), dtype=bool)
# 1002 tf.Tensor([ True], shape=(1,), dtype=bool)
# 1003 tf.Tensor([ True], shape=(1,), dtype=bool)
# 1004 tf.Tensor([ True], shape=(1,), dtype=bool)
# 1005 tf.Tensor([ True], shape=(1,), dtype=bool)
# 1006 tf.Tensor([ True], shape=(1,), dtype=bool)
# 1007 tf.Tensor([ True], shape=(1,), dtype=bool)
# 1008 tf.Tensor([ True], shape=(1,), dtype=bool)
# 1009 tf.Tensor([ True], shape=(1,), dtype=bool)
# 1010 tf.Tensor([ True], shape=(1,), dtype=bool)
# 1011 tf.Tensor([ True], shape=(1,), dtype=bool)
# 1012 tf.Tensor([ True], shape=(1,), dtype=bool)
# 1013 tf.Tensor([ True], shape=(1,), dtype=bool)
# 1014 tf.Tensor([ True], shape=(1,), dtype=bool)
# 1015 tf.Tensor([False], shape=(1,), dtype=bool)
# 1016 tf.Tensor([ True], shape=(1,), dtype=bool)
# 1017 tf.Tensor([ True], shape=(1,), dtype=bool)
# 1018 tf.Tensor([ True], shape=(1,), dtype=bool)
# 1019 tf.Tensor([ True], shape=(1,), dtype=bool)
# 1020 tf.Tensor([ True], shape=(1,), dtype=bool)
# 1021 tf.Tensor([ True], shape=(1,), dtype=bool)
# 1022 tf.Tensor([ True], shape=(1,), dtype=bool)
# 1023 tf.Tensor([ True], shape=(1,), dtype=bool)
# ...
# 4887 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4888 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4889 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4890 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4891 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4892 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4893 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4894 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4895 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4896 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4897 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4898 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4899 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4900 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4901 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4902 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4903 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4904 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4905 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4906 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4907 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4908 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4909 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4910 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4911 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4912 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4913 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4914 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4915 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4916 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4917 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4918 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4919 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4920 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4921 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4922 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4923 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4924 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4925 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4926 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4927 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4928 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4929 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4930 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4931 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4932 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4933 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4934 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4935 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4936 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4937 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4938 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4939 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4940 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4941 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4942 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4943 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4944 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4945 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4946 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4947 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4948 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4949 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4950 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4951 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4952 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4953 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4954 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4955 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4956 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4957 tf.Tensor([False], shape=(1,), dtype=bool)
# 4958 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4959 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4960 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4961 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4962 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4963 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4964 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4965 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4966 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4967 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4968 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4969 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4970 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4971 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4972 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4973 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4974 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4975 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4976 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4977 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4978 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4979 tf.Tensor([False], shape=(1,), dtype=bool)
# 4980 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4981 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4982 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4983 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4984 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4985 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4986 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4987 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4988 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4989 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4990 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4991 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4992 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4993 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4994 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4995 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4996 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4997 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4998 tf.Tensor([ True], shape=(1,), dtype=bool)
# 4999 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5000 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5001 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5002 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5003 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5004 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5005 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5006 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5007 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5008 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5009 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5010 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5011 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5012 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5013 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5014 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5015 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5016 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5017 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5018 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5019 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5020 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5021 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5022 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5023 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5024 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5025 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5026 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5027 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5028 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5029 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5030 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5031 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5032 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5033 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5034 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5035 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5036 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5037 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5038 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5039 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5040 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5041 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5042 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5043 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5044 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5045 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5046 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5047 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5048 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5049 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5050 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5051 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5052 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5053 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5054 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5055 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5056 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5057 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5058 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5059 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5060 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5061 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5062 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5063 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5064 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5065 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5066 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5067 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5068 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5069 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5070 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5071 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5072 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5073 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5074 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5075 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5076 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5077 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5078 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5079 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5080 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5081 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5082 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5083 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5084 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5085 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5086 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5087 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5088 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5089 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5090 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5091 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5092 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5093 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5094 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5095 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5096 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5097 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5098 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5099 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5100 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5101 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5102 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5103 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5104 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5105 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5106 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5107 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5108 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5109 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5110 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5111 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5112 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5113 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5114 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5115 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5116 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5117 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5118 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5119 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5120 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5121 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5122 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5123 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5124 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5125 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5126 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5127 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5128 tf.Tensor([False], shape=(1,), dtype=bool)
# 5129 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5130 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5131 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5132 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5133 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5134 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5135 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5136 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5137 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5138 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5139 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5140 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5141 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5142 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5143 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5144 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5145 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5146 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5147 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5148 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5149 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5150 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5151 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5152 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5153 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5154 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5155 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5156 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5157 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5158 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5159 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5160 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5161 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5162 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5163 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5164 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5165 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5166 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5167 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5168 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5169 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5170 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5171 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5172 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5173 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5174 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5175 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5176 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5177 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5178 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5179 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5180 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5181 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5182 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5183 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5184 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5185 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5186 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5187 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5188 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5189 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5190 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5191 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5192 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5193 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5194 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5195 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5196 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5197 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5198 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5199 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5200 tf.Tensor([False], shape=(1,), dtype=bool)
# 5201 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5202 tf.Tensor([False], shape=(1,), dtype=bool)
# 5203 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5204 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5205 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5206 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5207 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5208 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5209 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5210 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5211 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5212 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5213 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5214 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5215 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5216 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5217 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5218 tf.Tensor([ True], shape=(1,), dtype=bool)
# 5219 tf.Tensor([ True], shape=(1,), dtype=bool)
